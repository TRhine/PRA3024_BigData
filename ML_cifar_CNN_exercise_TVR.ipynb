# %% [markdown]
# <a href="https://colab.research.google.com/github/TRhine/PRA3024_BigData/blob/main/ML_cifar_CNN_exercise_TVR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Some data-handling functions to download/import.

# from https://github.com/yandexdataschool/mlhep2018/blob/master/day2-Tue/seminar-03-keras-cnn/seminar_tf_keras.ipynb
"""I load some cifar"""

import numpy as np
from sklearn.model_selection import train_test_split
import os, sys
if sys.version_info[0] == 2:
    from urllib import urlretrieve
    import cPickle as pickle

else:
    from urllib.request import urlretrieve
    import pickle

def unpickle(file):
    fo = open(file, 'rb')
    if sys.version_info[0] == 2:
        dict = pickle.load(fo)
    else:
        dict = pickle.load(fo,encoding='latin1')
    
    fo.close()
    return dict




def download_cifar10(path,
                     url='https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
                     tarname='cifar-10-python.tar.gz',):
    import tarfile
    if not os.path.exists(path):
        os.mkdir(path)
    
        

    urlretrieve(url, os.path.join(path,tarname))
    tfile = tarfile.open(os.path.join(path,tarname))
    tfile.extractall(path=path)
    

def load_cifar10(data_path=".",channels_last=False,test_size=0.2,random_state=1337):
    
    test_path = os.path.join(data_path,"cifar-10-batches-py/test_batch")
    train_paths = [os.path.join(data_path,"cifar-10-batches-py/data_batch_%i"%i) for i in range(1,6)]
    
    if not os.path.exists(test_path) or not all(list(map(os.path.exists, train_paths))):
        print ("Dataset not found. Downloading...")
        download_cifar10(data_path)

    train_batches = list(map(unpickle,train_paths))
    test_batch = unpickle(test_path)

    X = np.concatenate([batch["data"] for batch in train_batches]).reshape([-1,3,32,32]).astype('float32')/255
    y = np.concatenate([batch["labels"] for batch in train_batches]).astype('int32')
    X_train,X_val,y_train,y_val = train_test_split(X,y,
                                                   test_size=test_size,
                                                   random_state=random_state)
    
    X_test = test_batch["data"].reshape([-1,3,32,32]).astype('float32')/255
    y_test = np.array(test_batch["labels"]).astype('int32')
    
    if channels_last:
        #convert from [batch,3,H,W] to [batch,H,W,3]
        #WARNING! Make this is only necessary for tensorflow-style dim order
        #If you use theano-style dimensions in keras config, skip this cell
        X_train = X_train.transpose([0,2,3,1])
        X_val   = X_val.transpose([0,2,3,1])
        X_test  = X_test.transpose([0,2,3,1])

    
    return X_train,y_train,X_val,y_val,X_test,y_test

# %%
import tensorflow as tf
#gpu_options = tf.GPUOptions(allow_growth=True, per_process_gpu_memory_fraction=0.1) # restricts GPU load for multi-user nodes

import keras
from keras import backend as K
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.4.1
# 2.4.3

# %%
# Load the data samples

x_train,y_train,x_val,y_val,x_test,y_test = load_cifar10("cifar_data",channels_last=True)

NUM_CLASSES = 10
cifar10_classes = ["airplane", "automobile", "bird", "cat", "deer", 
                   "dog", "frog", "horse", "ship", "truck"]

print("Train samples:", x_train.shape, y_train.shape)
print("Test samples:", x_test.shape, y_test.shape)
print("Val samples:", x_val.shape, y_val.shape)
# Out:
# Dataset not found. Downloading...
# Train samples: (40000, 32, 32, 3) (40000,)
# Test samples: (10000, 32, 32, 3) (10000,)
# Val samples: (10000, 32, 32, 3) (10000,)

# %%
# show some random images from train, and their labels

cols = 8
rows = 2
fig = plt.figure(figsize=(2 * cols - 1, 2.5 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(y_train))
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        ax.imshow(x_train[random_index, :])
        ax.set_title(cifar10_classes[y_train[random_index]])
plt.show()

# %%
# normalize inputs
# convert class labels to one-hot encoded, should have shape (?, NUM_CLASSES)
# x_train = x_train.astype(np.float64) - 0.5

y_train = keras.utils.to_categorical(y_train, num_classes=10)

y_val = keras.utils.to_categorical(y_val, num_classes=10)

y_test = keras.utils.to_categorical(y_test, num_classes=10)

# %%
# import necessary building blocks
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout
from keras.layers.advanced_activations import LeakyReLU
from keras.initializers import Constant
from keras.regularizers import l1,l2,l1_l2
from keras.constraints import maxnorm

# %%
def make_model():
    """
    Define your model architecture here.
    Returns `Sequential` model.
    """

    ### STUDENT CODE HERE ###
    ### --> Build your convolutional neural network. 
    ### First, make a CNN layer with some small kernels to learn some basic features, with Conv2D.
    ### Then, add a Pooling layer to pick up the relevant kernels.
    ### Then, Flatten it and add some fully-connected (Dense) normal NN layers,
    ###  to learn the relevant combinations of low-level kernel features.
    ### Finally, some regularisation is advised, using a Dropout layer, to avoid local minima.
    ### Make sure the output is of the same shape as the number of labels we have,
    ### And the input is the same as the figures (which now have a 3rd dimension - color!)
    ### Again, use google to find information on these classes.

     model = Sequential()
    model.add(Conv2D(32, (3,3), padding='same', 
                     use_bias=False, input_shape = x_train.shape[1:]))
    model.add(MaxPooling2D(pool_size=(3,3)))
    model.add(Dropout(0.2))
    model.add(Conv2D(64, (3,3), padding='same',
                     use_bias=False, input_shape = x_train.shape[1:],
                     kernel_constraint=maxnorm(3)))
    model.add(MaxPooling2D(pool_size=(3,3)))
    model.add(Dropout(0.5))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add (Dense(NUM_CLASSES, kernel_regularizer=l1_l2(0.0002), activation='softmax', use_bias=False))
    model.summary()

    #This code is derived from the following site: 
    #https://cppsecrets.com/users/5271114105115104979810446114107495548525364103109971051084699111109/Advanced-Python-Projects-CIFAR-10-Image-Classification-using-Deep-Learning.php
    #I mostly copied from there while trying to understand what is written


    ### END STUDENT CODE ### 

    # Ensure normalized probabilities over the 10 classes
    model.add(Activation("softmax")) 

    return model

# %%
### STUDENT CODE HERE ###
### --> change the parameters below to perform a better training

INIT_LR = 3e-3  # initial learning rate
BATCH_SIZE = 32
EPOCHS = 50


K.clear_session()  # clear default graph
# don't call K.set_learning_phase() !!! (otherwise will enable dropout in train/test simultaneously)
model = make_model()  # define our model

# prepare model for fitting (loss, optimizer, etc)
model.compile(
    loss='categorical_crossentropy',  # we train 10-way classification
    optimizer=keras.optimizers.Adamax(lr=INIT_LR),  # for SGD.
    metrics=['accuracy']  # report accuracy during training
)

# fit model
model.fit(
    x_train, y_train,  # prepared data
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(x_val, y_val),
    shuffle=True,
)

# save weights to file to avoid re-training
model.save_weights("weights.h5")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        864
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18432
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5120
# =================================================================
# Total params: 2,122,080
# Trainable params: 2,122,080
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1250/1250 [==============================] - 6s 4ms/step - loss: 2.1914 - accuracy: 0.3081 - val_loss: 2.0416 - val_accuracy: 0.4398
# Epoch 2/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.0317 - accuracy: 0.4473 - val_loss: 1.9715 - val_accuracy: 0.5064
# Epoch 3/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.9796 - accuracy: 0.5008 - val_loss: 1.9429 - val_accuracy: 0.5356
# Epoch 4/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.9396 - accuracy: 0.5409 - val_loss: 1.9102 - val_accuracy: 0.5753
# Epoch 5/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.9130 - accuracy: 0.5684 - val_loss: 1.8869 - val_accuracy: 0.5960
# Epoch 6/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.8881 - accuracy: 0.5961 - val_loss: 1.8987 - val_accuracy: 0.5837
# Epoch 7/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.8768 - accuracy: 0.6082 - val_loss: 1.8731 - val_accuracy: 0.6088
# Epoch 8/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.8650 - accuracy: 0.6200 - val_loss: 1.8558 - val_accuracy: 0.6286
# Epoch 9/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.8458 - accuracy: 0.6400 - val_loss: 1.8451 - val_accuracy: 0.6384
# Epoch 10/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.8331 - accuracy: 0.6520 - val_loss: 1.8426 - val_accuracy: 0.6390
# Epoch 11/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.8232 - accuracy: 0.6653 - val_loss: 1.8405 - val_accuracy: 0.6437
# Epoch 12/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.8121 - accuracy: 0.6748 - val_loss: 1.8294 - val_accuracy: 0.6562
# Epoch 13/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7989 - accuracy: 0.6892 - val_loss: 1.8304 - val_accuracy: 0.6531
# Epoch 14/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7902 - accuracy: 0.6971 - val_loss: 1.8192 - val_accuracy: 0.6663
# Epoch 15/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7878 - accuracy: 0.6988 - val_loss: 1.8241 - val_accuracy: 0.6604
# Epoch 16/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7749 - accuracy: 0.7145 - val_loss: 1.8153 - val_accuracy: 0.6736
# Epoch 17/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7714 - accuracy: 0.7173 - val_loss: 1.8079 - val_accuracy: 0.6799
# Epoch 18/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7649 - accuracy: 0.7230 - val_loss: 1.8244 - val_accuracy: 0.6609
# Epoch 19/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7538 - accuracy: 0.7362 - val_loss: 1.8092 - val_accuracy: 0.6774
# Epoch 20/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7459 - accuracy: 0.7422 - val_loss: 1.8130 - val_accuracy: 0.6746
# Epoch 21/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7413 - accuracy: 0.7473 - val_loss: 1.7998 - val_accuracy: 0.6892
# Epoch 22/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7388 - accuracy: 0.7503 - val_loss: 1.8063 - val_accuracy: 0.6806
# Epoch 23/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7330 - accuracy: 0.7567 - val_loss: 1.8009 - val_accuracy: 0.6839
# Epoch 24/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7258 - accuracy: 0.7641 - val_loss: 1.7974 - val_accuracy: 0.6879
# Epoch 25/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7253 - accuracy: 0.7644 - val_loss: 1.7950 - val_accuracy: 0.6915
# Epoch 26/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7116 - accuracy: 0.7782 - val_loss: 1.7964 - val_accuracy: 0.6917
# Epoch 27/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7113 - accuracy: 0.7783 - val_loss: 1.7924 - val_accuracy: 0.6948
# Epoch 28/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7113 - accuracy: 0.7786 - val_loss: 1.7844 - val_accuracy: 0.7021
# Epoch 29/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7014 - accuracy: 0.7881 - val_loss: 1.7897 - val_accuracy: 0.6953
# Epoch 30/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6960 - accuracy: 0.7934 - val_loss: 1.7861 - val_accuracy: 0.6998
# Epoch 31/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6924 - accuracy: 0.7953 - val_loss: 1.7805 - val_accuracy: 0.7052
# Epoch 32/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6868 - accuracy: 0.8018 - val_loss: 1.7858 - val_accuracy: 0.7006
# Epoch 33/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6813 - accuracy: 0.8091 - val_loss: 1.7788 - val_accuracy: 0.7076
# Epoch 34/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6834 - accuracy: 0.8061 - val_loss: 1.7814 - val_accuracy: 0.7031
# Epoch 35/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6746 - accuracy: 0.8138 - val_loss: 1.7865 - val_accuracy: 0.6991
# Epoch 36/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6790 - accuracy: 0.8106 - val_loss: 1.7888 - val_accuracy: 0.6974
# Epoch 37/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6707 - accuracy: 0.8167 - val_loss: 1.7901 - val_accuracy: 0.6945
# Epoch 38/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6707 - accuracy: 0.8183 - val_loss: 1.7854 - val_accuracy: 0.7003
# Epoch 39/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6659 - accuracy: 0.8218 - val_loss: 1.7842 - val_accuracy: 0.6996
# Epoch 40/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6683 - accuracy: 0.8203 - val_loss: 1.7737 - val_accuracy: 0.7125
# Epoch 41/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6610 - accuracy: 0.8279 - val_loss: 1.7799 - val_accuracy: 0.7053
# Epoch 42/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6598 - accuracy: 0.8289 - val_loss: 1.7828 - val_accuracy: 0.7012
# Epoch 43/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6528 - accuracy: 0.8344 - val_loss: 1.7742 - val_accuracy: 0.7123
# Epoch 44/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6536 - accuracy: 0.8336 - val_loss: 1.7849 - val_accuracy: 0.6990
# Epoch 45/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6464 - accuracy: 0.8409 - val_loss: 1.7814 - val_accuracy: 0.7025
# Epoch 46/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6468 - accuracy: 0.8416 - val_loss: 1.7754 - val_accuracy: 0.7101
# Epoch 47/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6451 - accuracy: 0.8419 - val_loss: 1.7827 - val_accuracy: 0.7010
# Epoch 48/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6418 - accuracy: 0.8459 - val_loss: 1.7733 - val_accuracy: 0.7126
# Epoch 49/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6413 - accuracy: 0.8468 - val_loss: 1.7757 - val_accuracy: 0.7075
# Epoch 50/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.6440 - accuracy: 0.8429 - val_loss: 1.7763 - val_accuracy: 0.7071

# %%
# load weights from file (can call without model.fit)
model.load_weights("weights.h5")

# %%
# make test predictions
y_pred_test = model.predict_proba(x_test)
y_pred_test_classes = np.argmax(y_pred_test, axis=1)
y_pred_test_max_probas = np.max(y_pred_test, axis=1)
y_test_index = [list(onehot).index(1) for onehot in y_test]

# confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix', fontsize=16)
plt.imshow(confusion_matrix(y_test_index, y_pred_test_classes))
plt.xticks(np.arange(10), cifar10_classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), cifar10_classes, fontsize=12)
plt.colorbar()
plt.show()
print("Test accuracy:", accuracy_score(y_test_index, y_pred_test_classes))

# %%
# inspect preditions
cols = 8
rows = 2
fig = plt.figure(figsize=(2 * cols - 1, 3 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(y_test))
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        ax.imshow(x_test[random_index, :])
        pred_label = cifar10_classes[y_pred_test_classes[random_index]]
        pred_proba = y_pred_test_max_probas[random_index]
        true_label = cifar10_classes[y_test_index[random_index]]
        ax.set_title("pred: {}\nscore: {:.3}\ntrue: {}".format(
               pred_label, pred_proba, true_label
        ))
plt.show()

# %% [markdown]
# # Some tips on how to improve:
#
# * The ultimate quest is to create a network that has as high __accuracy__ as you can push it.
#
# ## Potential grading:
# * starting at zero points
# * +2 for describing your iteration path in a report below.
# * +2 for building a network that gets above 20% accuracy
# * +1 for beating each of these milestones on __TEST__ dataset:
#     * 50% (5 total)
#     * 60% (6 total)
#     * 65% (7 total)
#     * 70% (8 total)
#     * 75% (9 total)
#     * 80% (10 total)
#
# ## Bonus points
# Common ways to get bonus points are:
# * Get higher score, obviously.
# * Anything special about your NN. For example \"A super-small/fast NN that gets 80%\" gets a bonus.
# * Any detailed analysis of the results. (saliency maps, whatever)
#
#
# ## Tips on what can be done:
#
#  * __Network size__
#    * More neurons,
#    * More layers, ([lasagne docs](http://lasagne.readthedocs.org))
#    * Nonlinearities in the hidden layers
#    * tanh, relu, leaky relu, etc
#    * Larger networks may take more epochs to train, so don't discard your net just because it could didn't beat the baseline in 5 epochs.
#
#  * __Convolution layers__
#    * they __are a must__ unless you have any super-ideas
#    * `network = lasagne.layers.Conv2DLayer(prev_layer,`
#      `                       num_filters = n_neurons,`
#      `                       filter_size = (filter width, filter height),`
#      `                       nonlinearity = some_nonlinearity)`
#    * Warning! Training convolutional networks can take long without GPU. That's okay.
#      * If you are CPU-only, we still recomment to try a simple convolutional architecture
#      * a perfect option is if you can set it up to run at nighttime and check it up at the morning.
#      * Make reasonable layer size estimates. A 128-neuron first convolution is likely an overkill.
#      * __To reduce computation__ time by a factor in exchange for some accuracy drop, try using __stride__ parameter. A stride=2 convolution should take roughly 1/4 of the default (stride=1) one.
#
#    * Plenty other layers and architectures
#      * http://lasagne.readthedocs.org/en/latest/modules/layers.html
#      * batch normalization, pooling, etc
#
#
#  * __Early Stopping__
#    * Training for 100 epochs regardless of anything is probably a bad idea.
#    * Some networks converge over 5 epochs, others - over 500.
#    * Way to go: stop when validation score is 10 iterations past maximum
#
#
#  * __Faster optimization__ -
#    * rmsprop, nesterov_momentum, adam, adagrad and so on.
#      * Converge faster and sometimes reach better optima
#      * It might make sense to tweak learning rate/momentum, other learning parameters, batch size and number of epochs
#    * __BatchNormalization__ (lasagne.layers.batch_norm) FTW!
#
#
#  * __Regularize__ to prevent overfitting
#    * Add some L2 weight norm to the loss function, theano will do the rest
#      * Can be done manually or via - http://lasagne.readthedocs.org/en/latest/modules/regularization.html
#    * Dropout - to prevent overfitting
#      * `lasagne.layers.DropoutLayer(prev_layer, p=probability_to_zero_out)`
#      * Don't overdo it. Check if it actually makes your network better
#
#
#  * __Data augmentation__ - getting 5x as large dataset for free is a great deal
#    * Zoom-in+slice = move
#    * Rotate+zoom(to remove black stripes)
#    * any other perturbations
#    * Add Noize (easiest: GaussianNoizeLayer)
#    * Simple way to do that (if you have PIL/Image):
#      * ```from scipy.misc import imrotate,imresize```
#      * and a few slicing
#    * Stay realistic. There's usually no point in flipping dogs upside down as that is not the way you usually see them.

# %%
# Input code was heavily influenced by code taken from the site included in the code section.
# The model incorporates 2x 2D Convolution Layer, the first has 32 filters and the latter uses 64 filters. Padding was "same" so that the ouput 
# has the same dimensions as the input. The input shape is the first index of the x_trainshape variable created previously. 
# A dropout was added ot prevent overfitting as outlined in the instructions above. This was set to a value of 0.2 and 0.5 respectively.

# After some tinkering, the intial learning rate was set to 3e-3 and the epochs to 50. Playing around with the batch size had some effect but
# 32 was ideal.
